# %%
include("src/PDI_BC.jl")
include("src/readPRP.jl")
# Out:
# Read_PRP_instance (generic function with 1 method)

# %%
LP = PDI_BC(Read_PRP_instance("./PRP_instances/A_014_#ABS1_15_1.prp"))
# Out:
# Version identifier: 20.1.0.0 | 2020-11-10 | 9bedb6d68
# CPXPARAM_Threads                                 1
# CPXPARAM_TimeLimit                               3600
# Generic callback                                 0x20
# Tried aggregator 2 times.
# MIP Presolve eliminated 378 rows and 90 columns.
# MIP Presolve modified 1299 coefficients.
# Aggregator did 27 substitutions.
# Reduced MIP has 327 rows, 1605 columns, and 3171 nonzeros.
# Reduced MIP has 1350 binaries, 96 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (3.29 ticks)
# Probing time = 0.00 sec. (2.00 ticks)
# Tried aggregator 2 times.
# Aggregator did 4 substitutions.
# Reduced MIP has 323 rows, 1601 columns, and 3159 nonzeros.
# Reduced MIP has 1350 binaries, 155 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (1.74 ticks)
# Probing time = 0.00 sec. (1.98 ticks)
# Clique table members: 177.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# ...

# %%
    println(solution_summary(LP, verbose=true))
# Out:
# * Solver : CPLEX
#
# * Status
#   Termination status : TIME_LIMIT
#   Primal status      : NO_SOLUTION
#   Dual status        : NO_SOLUTION
#   Result count       : 0
#   Has duals          : false
#   Message from the solver:
#   "time limit exceeded, no integer solution"
#
# * Candidate solution
#   Objective bound      : 3.50400e+04
#
# * Work counters
#   Solve time (sec)   : 3.60002e+03
#   Simplex iterations : 0
#   Barrier iterations : 0
#   Node count         : 812704
#
# CPLEX Error  1217: No solution exists.
# CPLEX Error  1217: No solution exists.
# CPLEX Error  1217: No solution exists.
